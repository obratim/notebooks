# %%
var random = new Random();

# %%
double RandomFloat(int iterations)
{
    var total = 0.0;
    for (var i = 0; i < iterations; ++i)
    {
        total += random.NextDouble() - random.NextDouble();
    }
    return total / iterations;
}

IEnumerable<double> RandomFloats(int count, int iterations)
{
    for (var i = 0; i < count; ++i)
        yield return RandomFloat(iterations);
}

# %%
var data = Enumerable.Range(1, 300).Select(i => i * 5).Select(i => (iterations: i, values: RandomFloats(300, i)));

# %%
#r "nuget:XPlot.Plotly.Interactive"
using XPlot.Plotly;
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>XPlot.Plotly.Interactive, 4.0.7</span></li></ul></div></div>
# Loading extensions from `C:\Users\Admin\.nuget\packages\xplot.plotly.interactive\4.0.7\lib\net7.0\XPlot.Plotly.Interactive.dll`
# Configuring PowerShell Kernel for XPlot.Plotly integration.
# Installed support for XPlot.Plotly.

# %%
Chart.Plot(
    new Histogram
    {
        x = data.SelectMany(y => y.values),
        nbinsx = 1000,
    }
)
# Out:
# <!DOCTYPE html>
# <div style="width: 900px; height: 500px;" id="a1be2e45-465a-456b-9bb5-105302a8321b"></div><script type="text/javascript">
#
# var renderPlotly = function() {
#     var xplotRequire = require.config({context:'xplot-3.0.1',paths:{plotly:'https://cdn.plot.ly/plotly-1.49.2.min'}}) || require;
#     xplotRequire(['plotly'], function(Plotly) {
#
#             var data = [{"type":"histogram","x":[-0.13343612992922455,0.1272944424497999,-0.21346513796353958,-0.009722417733182298,-0.11906711673382189,-0.015479465262961022,-0.08427358404606415,-0.016444741554338328,-0.08627436893627016,-0.0966123044817968,0.022085887792307024,-0.15345481564506838,-0.1262761189476453,0.10130161890990383,-0.17874930273664838,-0.20252601605428894,-0.08424678115980118,-0.06275221905012136,0.06699464735073105,-0.020063881589458488,0.27732860378748125,0.1551880030387605,0.2439520366789457,-0.10737088872841123,0.045968007552378266,-0.08433355302457397,0.26020690438639527,-0.13081480213507074,-0.1389895064002514,-0.142039230249078,-0.025783443202941993,0.05926941802296744,-0.3026749384999402,0.13350245425354243,-0.03892843375005941,-0.19127079948323564,-0.2690094701181678,-0.31302328126119466,0.11146410900474595,0.026848222036892654,-0.19180356534468315,-0.05183919014842224,-0.005795313691490489,-0.4896708873252923,0.19906245996442054,0.4051507924149547,0.14922332146170694,-0.05802877158139157,0.18092917027754019,-0.03268233251165471,0.08537394006583932,-0.08822958603198768,0.029365720249703898,0.20229634850188755,-0.2689100376067811,0.09333794674281262,-0.08870621126543923,0.047485598910542694,0.11930526285139789,0.38327177336964907,0.1511259653972628,0.2813934851991493,-0.019982525415897224,0.09355517912112528,0.14679420620274486,0.159036541082361,-0.07787405536052819,0.20100199221665832,-0.053156026961360923,0.20632615947428432,-0.1760254504831898,-0.34982537215192516,0.0377817523179584,0.0510955269692057,0.4832843150128346,0.04775530174217557,0.08593570643970927,0.20298256748651772,-4.16244402376309E-05,-0.03286522845671254,-0.24373676870282282,-0.21323835034447686,-0.020365733550617125,-0.024196046012539597,-0.1828580058397108,0.17459567169296686,-0.22994382026563245,-0.16029602814254434,0.19592226455683864,-0.1910795866044737,0.053618680231692604,0.07491406597273262,0.3512094154531608,-0.3187072292377958,0.22771792891601988,0.1175471207374293,-0.2984009938578299,0.3041418197529223,-0
i "nuget:https://pkgs.dev.azure.com/dnceng/public/_packaging/dotnet-tools/nuget/v3/index.json"

#r "nuget:Microsoft.DotNet.Interactive.ExtensionLab, *-*"
#r "nuget:nteract.InteractiveExtension"
#r "nuget:SandDance.InteractiveExtension"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.DotNet.Interactive.ExtensionLab, 1.0.0-beta.23606.2</span></li><li><span>nteract.InteractiveExtension, 1.0.91</span></li><li><span>SandDance.InteractiveExtension, 1.0.126</span></li></ul></div></div>
# Loading extension script from `C:\Users\Admin\.nuget\packages\sanddance.interactiveextension\1.0.126\interactive-extensions\dotnet\extension.dib`
# <details><summary>Explore data visually using the <a href="https://github.com/microsoft/SandDance">SandDance Explorer</a>.</summary>
#     <p>This extension adds the ability to sort, filter, and visualize data using the <a href="https://github.com/microsoft/SandDance">SandDance Explorer</a>. Use the <code>ExploreWithSandDance()</code> extension method with variables of type <code>JsonElement</code>, <code>IEnumerable<T></code> or <code>IDataView</code> to render the data explorer.</p>
# <pre>
#     <code>
#     using Microsoft.Data.Analysis;
#     using System.Collections.Generic;
#     using Microsoft.ML;
#
#     var dataFrame = DataFrame.LoadCsv("./Data.csv");
#
#     dataFrame.ExploreWithSandDance().Display();
#     </code>
# </pre>
# <p>To set the SandDance Explorer use the following code</p>
# <pre>
#     <code>
#     DataExplorer.SetDefault<TabularDataResource, SandDanceDataExplorer>();
#     </code>
# </pre>
#     <img src="https://user-images.githubusercontent.com/11507384/54236654-52d42800-44d1-11e9-859e-6c5d297a46d2.gif" width="30%">
#     </details>
# Loading extension script from `C:\Users\Admin\.nuget\packages\microsoft.dotnet.interactive.extensionlab\1.0.0-beta.23606.2\interactive-extensions\dotnet\extension.dib`
# <details><summary>Create strongly-typed dataframes using<code>#!linqify</code>.</summary>
#     <p>The <code>#!linqify</code> magic command replaces a <a href="https://www.nuget.org/packages/Microsoft.Data.Analysis/"><code>Microsoft.Data.Analysis.DataFrame</code></a> variable with a generated, strongly-typed data frame, allowing the use of LINQ operations over the contained data.</p>
#     </details>
# <details><summary>ExplainCode</summary>
#     <p>This extension generates Sequence diagrams from csharp code using Mermaid kernel.</p>
#     </details>
# <details><summary>Inspect code compilation details using the <code>#!inspect</code> magic command.</summary>
#     <p>The <code>#!inspect</code> magic command allows you to see the C# decompilation, IL, and JIT Asm for the code in a C# cell.</p>
#     <img src="https://user-images.githubusercontent.com/547415/109560515-d5749a00-7a90-11eb-9fa3-51b737345bb4.png" width="75%" />
#     </details>
# <details><summary>Use the <code>#!record</code> magic command to keep a transcript of the code you run.</summary>
#     <p>Once you enable transcripts using <code>#!record</code>, each code submission (including re-running cells) is recorded in the specified file. The JSON format used is the same format recognized by the .NET Interactive <code>stdio</code> and <code>http</code> APIs and can be used to replay an interactive session via automation.</p>
#     <img src="https://user-images.githubusercontent.com/547415/109562409-343b1300-7a93-11eb-8ebf-79bb6af028cf.png" width="75%" />
#     </details>
# Loading extensions from `C:\Users\Admin\.nuget\packages\microsoft.data.analysis\0.21.0\interactive-extensions\dotnet\Microsoft.Data.Analysis.Interactive.dll`

# %%
var snapshot2 = data.Select(x => (iterations: x.iterations, values: x.values.ToList())).ToList();
var matrix = snapshot.Select(x => new { iterations = x.iterations, avg = x.values.Average(), min = x.values.Min(), max = x.values.Max() }).ToList();

matrix.ExploreWithNteract()
# Out:
# <div style="background-color:white;">
# <div id="2a749ae6e0a244db8449da3e44ae0a75" style="height: 100ch ;margin: 2px;">
# </div>
# <script type="text/javascript">
#
# renderNteractDataExplorer_2a749ae6e0a244db8449da3e44ae0a75 = () => {
#
#     configureRequireFromExtension('nteract','1.0.0')(['nteract/nteractapi'], (nteract) => {
#
#         nteract.createDataExplorer({
#             data: {
#   "profile": "tabular-data-resource",
#   "schema": {
#     "primaryKey": [],
#     "fields": [
#       {
#         "type": "integer",
#         "name": "iterations"
#       },
#       {
#         "type": "number",
#         "name": "avg"
#       },
#       {
#         "type": "number",
#         "name": "min"
#       },
#       {
#         "type": "number",
#         "name": "max"
#       }
#     ]
#   },
#   "data": [
#     {
#       "iterations": 5,
#       "avg": 0.016614146082326454,
#       "min": -0.46696816993233103,
#       "max": 0.466134982893233
#     },
#     {
#       "iterations": 10,
#       "avg": 0.00034333192077109424,
#       "min": -0.2788006585576144,
#       "max": 0.4029573156637619
#     },
#     {
#       "iterations": 15,
#       "avg": -0.002067954929059812,
#       "min": -0.2919607319027905,
#       "max": 0.27384777869256294
#     },
#     {
#       "iterations": 20,
#       "avg": -0.012820420722667892,
#       "min": -0.2640062138452972,
#       "max": 0.2099635926356287
#     },
#     {
#       "iterations": 25,
#       "avg": 0.0001680809721210601,
#       "min": -0.24487536691939013,
#       "max": 0.203605180102054
#     },
#     {
#       "iterations": 30,
#       "avg": -0.006099693423143968,
#       "min": -0.23432694225616352,
#       "max": 0.1664564559811593
#     },
#     {
#       "iterations": 35,
#       "avg": 0.0016869307092997683,
#       "min": -0.17237516995062133,
#       "max": 0.20153933193615978
#     },
#     {
#       "iterations": 40,
#       "avg": -0.0005758400734311453,
#       "min": -0.1767029485803035,
#       "max": 0.18027180444801633
#     },
#     {
#       "iterations": 45,
#       "avg": -0.0021914793493750377,
#       "min": -0.19346199064208797,
#       "max": 0.1482260333949221
#     },
#     {
#       "iterations": 50,
#       "avg": 0.0021697778389352853,
#       "min": -0.1485376674784318,
#       "max": 0.1598219101150351
#     },
#     {
#       "iterations": 55,
#       "avg": 0.00287535045283391,
#       "min": -0.14439139884292743,
#       "max": 0.1332048912753921
#     },
#     {
#       "iterations": 60,
#       "avg": -0.001661879539118509,
#       "min": -0.16498872750433818,
#       "max": 0.1558951232333377
#     },
#     {
#       "iterations": 65,
#       "avg": 0.00030435850883885973,
#       "min": -0.12397720652556184,
#       "max": 0.12025338734986642
#     },
#     {
#       "iterations": 70,
#       "avg": -0.001672621501989386,
#       "min": -0.12720220817163094,
#       "max": 0.11276833295683064
#     },
#     {
#       "iterations": 75,
#       "avg": -0.001526192749856393,
#       "min": -0.15059963731064901,
#       "max": 0.11323903633514078
#     },
#     {
#       "iterations": 80,
#       "avg": -0.002630713435232467,
#       "min": -0.12986627275190715,
#       "max": 0.137555782533107
#     },
#     {
#       "iterations": 85,
#       "avg": 0.00044898064511233494,
#       "min": -0.1293741574707378,
#       "max": 0.10569041629790218
#     },
#     {
#       "iterations": 90,
#       "avg": 0.003397248859877397,
#       "min": -0.11521445901916547,
#       "max": 0.14203417612387825
#     },
#     {
#       "iterations": 95,
#       "avg": 0.0025535115708263845,
#       "min": -0.11308967928467889,
#       "max": 0.13687744102691368
#     },
#     {
#       "iterations": 100,
#       "avg": 0.0005478599433764702,
#       "min": -0.12678430340459687,
#       "max": 0.10615081437802636
#     },
#     {
#       "iterations": 105,
#       "avg": 0.0014754752701323416,
#       "min": -0.10390474819460487,
#       "max": 0.1274353106487293
#     },
#     {
#       "iterations": 110,
#       "avg": -0.0013607763521479696,
#       "min": -0.09378899848583556,
#       "max": 0.08588047326938432
#     },
#     {
#       "iterations": 115,
#       "avg": -0.0003359040642156846,
#       "min": -0.10785236020267526,
#       "max": 0.10519126270017856
#     },
#     {
#       "iterations": 120,
#       "avg": 0.0007913545132456316,
#       "min": -0.08965108640720967,
#       "max": 0.11304908282303833
#     },
#     {
#       "iterations": 125,
#       "avg": -0.0029638841393665517,
#       "min": -0.1182687244981838,
#       "max": 0.08388593135374324
#     },
#     {
#       "iterations": 130,
#       "avg": -0.0006316437150933521,
#       "min": -0.11979863444982533,
#       "max": 0.10037964426892998
#     },
#     {
#       "iterations": 135,
#       "avg": -0.003427102063241268,
#       "min": -0.12384378276449776,
#       "max": 0.10037256092443635
#     },
#     {
#       "iterations": 140,
#       "avg": 0.0037793566793769416,
#       "min": -0.09627123927230448,
#       "max": 0.11853713930709281
#     },
#     {
#       "iterations": 145,
#       "avg": 0.002086632545971221,
#       "min": -0.10904724797838584,
#       "max": 0.10273434167564718
#     },
#     {
#       "iterations": 150,
#       "avg": 0.00436620990620891,
#       "min": -0.0972247985113958,
#       "max": 0.107497318947252
#     },
#     {
#       "iterations": 155,
#       "avg": -0.002334301123264233,
#       "min": -0.09861100406891624,
#       "max": 0.0949864060795898
#     },
#     {
#       "iterations": 160,
#       "avg": -0.00030866965776830024,
#       "min": -0.07702187408615445,
#       "max": 0.08377534048480689
#     },
#     {
#       "iterations": 165,
#       "avg": 0.0007125228862492842,
#       "min": -0.08716151989381915,
#       "max": 0.08326980724170023
#     },
#     {
#       "iterations": 170,
#       "avg": 0.003075640847656443,
#       "min": -0.07860021115424665,
#       "max": 0.09532336790525153
#     },
#     {
#       "iterations": 175,
#       "avg": -0.004179327081549004,
#       "min": -0.10462483267058813,
#       "max": 0.06507923063447363
#     },
#     {
#       "iterations": 180,
#       "avg": 0.00044658571063579944,
#       "min": -0.07563365768898458,
#       "max": 0.10945364209319139
#     },
#     {
#       "iterations": 185,
#       "avg": 0.00019483435698430674,
#       "min": -0.0919950364910844,
#       "max": 0.09033141724970332
#     },
#     {
#       "iterations": 190,
#       "avg": -9.242465618362173E-05,
#       "min": -0.0773909098652394,
#       "max": 0.08994131436115663
#     },
#     {
#       "iterations": 195,
#       "avg": 0.002860618929190661,
#       "min": -0.06868943691992165,
#       "max": 0.10174994517813352
#     },
#     {
#       "iterations": 200,
#       "avg": -9.727144482943042E-05,
#       "min": -0.0639585989196258,
#       "max": 0.06984184172211873
#     },
#     {
#       "iterations": 205,
#       "avg": 0.001271656351279193,
#       "min": -0.07542147026143659,
#       "max": 0.07379085396065785
#     },
#     {
#       "iterations": 210,
#       "avg": 0.0022595888532761397,
#       "min": -0.07436097345515318,
#       "max": 0.07607056454554802
#     },
#     {
#       "iterations": 215,
#       "avg": 0.000514009202786281,
#       "min": -0.05877048601992224,
#       "max": 0.07022006171203846
#     },
#     {
#       "iterations": 220,
#       "avg": 0.00034540732545119897,
#       "min": -0.08519163357189434,
#       "max": 0.07773262633096231
#     },
#     {
#       "iterations": 225,
#       "avg": 0.001584812349131844,
#       "min": -0.06271555768613932,
#       "max": 0.08843954020601849
#     },
#     {
#       "iterations": 230,
#       "avg": -0.0014413205568979575,
#       "min": -0.06339075524807657,
#       "max": 0.07640742379689507
#     },
#     {
#       "iterations": 235,
#       "avg": -0.00012967732180772047,
#       "min": -0.09516072754275373,
#       "max": 0.08640393849757967
#     },
#     {
#       "iterations": 240,
#       "avg": -0.0004156630189547825,
#       "min": -0.08193221258439089,
#       "max": 0.08018427942371573
#     },
#     {
#       "iterations": 245,
#       "avg": -0.0006461018215089173,
#       "min": -0.060383474422001523,
#       "max": 0.0822945949239778
#     },
#     {
#       "iterations": 250,
#       "avg": -0.00028682928273667565,
#       "min": -0.06509315802650066,
#       "max": 0.06576118803963173
#     },
#     {
#       "iterations": 255,
#       "avg": -0.002394015433716303,
#       "min": -0.07931764784400491,
#       "max": 0.06635324313306962
#     },
#     {
#       "iterations": 260,

# %%
matrix.ExploreWithSandDance()
# Out:
# <div style="background-color:white;">
# <div id="b8830bf4e8f54726bee20b09ff0cd515" style="height: 100ch ;margin: 2px;">
# </div>
# <script type="text/javascript">
#
# renderSandDanceExplorer_b8830bf4e8f54726bee20b09ff0cd515 = () => {
#
#     (require.config({ 'paths': { 'context': '1.0.100', 'sandDanceUri' : 'https://colombod.github.io/dotnet-interactive-cdn/extensionlab/1.0.100/SandDance/sanddanceapi', 'urlArgs': 'cacheBuster=a5162689d1984a26a3d47abcda07abb7' }}) || require)(['sandDanceUri'], (sandDance) => {
#
#         sandDance.createSandDanceExplorer({
#             data: {
#   "profile": "tabular-data-resource",
#   "schema": {
#     "primaryKey": [],
#     "fields": [
#       {
#         "type": "integer",
#         "name": "iterations"
#       },
#       {
#         "type": "number",
#         "name": "avg"
#       },
#       {
#         "type": "number",
#         "name": "min"
#       },
#       {
#         "type": "number",
#         "name": "max"
#       }
#     ]
#   },
#   "data": [
#     {
#       "iterations": 5,
#       "avg": 0.016614146082326454,
#       "min": -0.46696816993233103,
#       "max": 0.466134982893233
#     },
#     {
#       "iterations": 10,
#       "avg": 0.00034333192077109424,
#       "min": -0.2788006585576144,
#       "max": 0.4029573156637619
#     },
#     {
#       "iterations": 15,
#       "avg": -0.002067954929059812,
#       "min": -0.2919607319027905,
#       "max": 0.27384777869256294
#     },
#     {
#       "iterations": 20,
#       "avg": -0.012820420722667892,
#       "min": -0.2640062138452972,
#       "max": 0.2099635926356287
#     },
#     {
#       "iterations": 25,
#       "avg": 0.0001680809721210601,
#       "min": -0.24487536691939013,
#       "max": 0.203605180102054
#     },
#     {
#       "iterations": 30,
#       "avg": -0.006099693423143968,
#       "min": -0.23432694225616352,
#       "max": 0.1664564559811593
#     },
#     {
#       "iterations": 35,
#       "avg": 0.0016869307092997683,
#       "min": -0.17237516995062133,
#       "max": 0.20153933193615978
#     },
#     {
#       "iterations": 40,
#       "avg": -0.0005758400734311453,
#       "min": -0.1767029485803035,
#       "max": 0.18027180444801633
#     },
#     {
#       "iterations": 45,
#       "avg": -0.0021914793493750377,
#       "min": -0.19346199064208797,
#       "max": 0.1482260333949221
#     },
#     {
#       "iterations": 50,
#       "avg": 0.0021697778389352853,
#       "min": -0.1485376674784318,
#       "max": 0.1598219101150351
#     },
#     {
#       "iterations": 55,
#       "avg": 0.00287535045283391,
#       "min": -0.14439139884292743,
#       "max": 0.1332048912753921
#     },
#     {
#       "iterations": 60,
#       "avg": -0.001661879539118509,
#       "min": -0.16498872750433818,
#       "max": 0.1558951232333377
#     },
#     {
#       "iterations": 65,
#       "avg": 0.00030435850883885973,
#       "min": -0.12397720652556184,
#       "max": 0.12025338734986642
#     },
#     {
#       "iterations": 70,
#       "avg": -0.001672621501989386,
#       "min": -0.12720220817163094,
#       "max": 0.11276833295683064
#     },
#     {
#       "iterations": 75,
#       "avg": -0.001526192749856393,
#       "min": -0.15059963731064901,
#       "max": 0.11323903633514078
#     },
#     {
#       "iterations": 80,
#       "avg": -0.002630713435232467,
#       "min": -0.12986627275190715,
#       "max": 0.137555782533107
#     },
#     {
#       "iterations": 85,
#       "avg": 0.00044898064511233494,
#       "min": -0.1293741574707378,
#       "max": 0.10569041629790218
#     },
#     {
#       "iterations": 90,
#       "avg": 0.003397248859877397,
#       "min": -0.11521445901916547,
#       "max": 0.14203417612387825
#     },
#     {
#       "iterations": 95,
#       "avg": 0.0025535115708263845,
#       "min": -0.11308967928467889,
#       "max": 0.13687744102691368
#     },
#     {
#       "iterations": 100,
#       "avg": 0.0005478599433764702,
#       "min": -0.12678430340459687,
#       "max": 0.10615081437802636
#     },
#     {
#       "iterations": 105,
#       "avg": 0.0014754752701323416,
#       "min": -0.10390474819460487,
#       "max": 0.1274353106487293
#     },
#     {
#       "iterations": 110,
#       "avg": -0.0013607763521479696,
#       "min": -0.09378899848583556,
#       "max": 0.08588047326938432
#     },
#     {
#       "iterations": 115,
#       "avg": -0.0003359040642156846,
#       "min": -0.10785236020267526,
#       "max": 0.10519126270017856
#     },
#     {
#       "iterations": 120,
#       "avg": 0.0007913545132456316,
#       "min": -0.08965108640720967,
#       "max": 0.11304908282303833
#     },
#     {
#       "iterations": 125,
#       "avg": -0.0029638841393665517,
#       "min": -0.1182687244981838,
#       "max": 0.08388593135374324
#     },
#     {
#       "iterations": 130,
#       "avg": -0.0006316437150933521,
#       "min": -0.11979863444982533,
#       "max": 0.10037964426892998
#     },
#     {
#       "iterations": 135,
#       "avg": -0.003427102063241268,
#       "min": -0.12384378276449776,
#       "max": 0.10037256092443635
#     },
#     {
#       "iterations": 140,
#       "avg": 0.0037793566793769416,
#       "min": -0.09627123927230448,
#       "max": 0.11853713930709281
#     },
#     {
#       "iterations": 145,
#       "avg": 0.002086632545971221,
#       "min": -0.10904724797838584,
#       "max": 0.10273434167564718
#     },
#     {
#       "iterations": 150,
#       "avg": 0.00436620990620891,
#       "min": -0.0972247985113958,
#       "max": 0.107497318947252
#     },
#     {
#       "iterations": 155,
#       "avg": -0.002334301123264233,
#       "min": -0.09861100406891624,
#       "max": 0.0949864060795898
#     },
#     {
#       "iterations": 160,
#       "avg": -0.00030866965776830024,
#       "min": -0.07702187408615445,
#       "max": 0.08377534048480689
#     },
#     {
#       "iterations": 165,
#       "avg": 0.0007125228862492842,
#       "min": -0.08716151989381915,
#       "max": 0.08326980724170023
#     },
#     {
#       "iterations": 170,
#       "avg": 0.003075640847656443,
#       "min": -0.07860021115424665,
#       "max": 0.09532336790525153
#     },
#     {
#       "iterations": 175,
#       "avg": -0.004179327081549004,
#       "min": -0.10462483267058813,
#       "max": 0.06507923063447363
#     },
#     {
#       "iterations": 180,
#       "avg": 0.00044658571063579944,
#       "min": -0.07563365768898458,
#       "max": 0.10945364209319139
#     },
#     {
#       "iterations": 185,
#       "avg": 0.00019483435698430674,
#       "min": -0.0919950364910844,
#       "max": 0.09033141724970332
#     },
#     {
#       "iterations": 190,
#       "avg": -9.242465618362173E-05,
#       "min": -0.0773909098652394,
#       "max": 0.08994131436115663
#     },
#     {
#       "iterations": 195,
#       "avg": 0.002860618929190661,
#       "min": -0.06868943691992165,
#       "max": 0.10174994517813352
#     },
#     {
#       "iterations": 200,
#       "avg": -9.727144482943042E-05,
#       "min": -0.0639585989196258,
#       "max": 0.06984184172211873
#     },
#     {
#       "iterations": 205,
#       "avg": 0.001271656351279193,
#       "min": -0.07542147026143659,
#       "max": 0.07379085396065785
#     },
#     {
#       "iterations": 210,
#       "avg": 0.0022595888532761397,
#       "min": -0.07436097345515318,
#       "max": 0.07607056454554802
#     },
#     {
#       "iterations": 215,
#       "avg": 0.000514009202786281,
#       "min": -0.05877048601992224,
#       "max": 0.07022006171203846
#     },
#     {
#       "iterations": 220,
#       "avg": 0.00034540732545119897,
#       "min": -0.08519163357189434,
#       "max": 0.07773262633096231
#     },
#     {
#       "iterations": 225,
#       "avg": 0.001584812349131844,
#       "min": -0.06271555768613932,
#       "max": 0.08843954020601849
#     },
#     {
#       "iterations": 230,
#       "avg": -0.0014413205568979575,
#       "min": -0.06339075524807657,
#       "max": 0.07640742379689507
#     },
#     {
#       "iterations": 235,
#       "avg": -0.00012967732180772047,
#       "min": -0.09516072754275373,
#       "max": 0.08640393849757967
#     },
#     {
#       "iterations": 240,
#       "avg": -0.0004156630189547825,
#       "min": -0.08193221258439089,
#       "max": 0.08018427942371573
#     },
#     {
#       "iterations": 245,
#       "avg": -0.0006461018215089173,
#       "min": -0.060383474422001523,
#       "max": 0.0822945949239778
#     },
#     {
#       "iterations": 250,
#       "avg": -0.00028682928273667565,
#       "min": -0.06509315802650066,
#       "max": 0.0657611880396
