# %%
var random = new Random();
double RandomFloat(int iterations)
{
    var total = 0.0;
    for (var i = 0; i < iterations; ++i)
    {
        total += random.NextDouble() - random.NextDouble();
    }
    return total / iterations;
}

IEnumerable<double> RandomFloats(int count, int iterations)
{
    for (var i = 0; i < count; ++i)
        yield return RandomFloat(iterations);
}

var data = Enumerable.Range(1, 300).Select(i => i * 5).Select(i => (iterations: i, values: RandomFloats(300, i)));
var snapshot = data.Select(x => (iterations: x.iterations, values: x.values.ToList())).ToList();

# %%
#r "nuget:nteract.InteractiveExtension, *-*"

var snapshot2 = data.Select(x => (iterations: x.iterations, values: x.values.ToList())).ToList();
var matrix = snapshot.Select(x => new { iterations = x.iterations, avg = x.values.Average(), min = x.values.Min(), max = x.values.Max() }).ToList();

matrix.ExploreWithNteract()
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>nteract.InteractiveExtension, 1.0.91</span></li></ul></div></div>
# <div style="background-color:white;">
# <div id="efd284a36b4c4742a1442ded526b1cf5" style="height: 100ch ;margin: 2px;">
# </div>
# <script type="text/javascript">
#
# renderNteractDataExplorer_efd284a36b4c4742a1442ded526b1cf5 = () => {
#
#     configureRequireFromExtension('nteract','1.0.0')(['nteract/nteractapi'], (nteract) => {
#
#         nteract.createDataExplorer({
#             data: {
#   "profile": "tabular-data-resource",
#   "schema": {
#     "primaryKey": [],
#     "fields": [
#       {
#         "type": "integer",
#         "name": "iterations"
#       },
#       {
#         "type": "number",
#         "name": "avg"
#       },
#       {
#         "type": "number",
#         "name": "min"
#       },
#       {
#         "type": "number",
#         "name": "max"
#       }
#     ]
#   },
#   "data": [
#     {
#       "iterations": 5,
#       "avg": -0.011567597675889305,
#       "min": -0.5456341171450456,
#       "max": 0.4798036389617938
#     },
#     {
#       "iterations": 10,
#       "avg": 0.008202718258155018,
#       "min": -0.31295213216966855,
#       "max": 0.41199712176066805
#     },
#     {
#       "iterations": 15,
#       "avg": 0.00030380959482348093,
#       "min": -0.3394320526123221,
#       "max": 0.3477873668688965
#     },
#     {
#       "iterations": 20,
#       "avg": 0.003097709908485092,
#       "min": -0.22194671838619628,
#       "max": 0.22074642177282033
#     },
#     {
#       "iterations": 25,
#       "avg": 0.005157810358464063,
#       "min": -0.2498831401390783,
#       "max": 0.2242923285559859
#     },
#     {
#       "iterations": 30,
#       "avg": 0.0009178971342518705,
#       "min": -0.19007185285503647,
#       "max": 0.1881973725507602
#     },
#     {
#       "iterations": 35,
#       "avg": -0.0010787074494213141,
#       "min": -0.20503105671231045,
#       "max": 0.18335504401837346
#     },
#     {
#       "iterations": 40,
#       "avg": -0.005442156448033693,
#       "min": -0.17595176409691665,
#       "max": 0.1662421074541934
#     },
#     {
#       "iterations": 45,
#       "avg": -0.0038681544014154,
#       "min": -0.15253187620564457,
#       "max": 0.16433046732590867
#     },
#     {
#       "iterations": 50,
#       "avg": 0.0017605758876845302,
#       "min": -0.1577797297237025,
#       "max": 0.16197314279071737
#     },
#     {
#       "iterations": 55,
#       "avg": -0.005119506610075755,
#       "min": -0.21687826342536023,
#       "max": 0.14870973362093354
#     },
#     {
#       "iterations": 60,
#       "avg": 0.0039876559148451516,
#       "min": -0.12106836224660486,
#       "max": 0.1944334321780166
#     },
#     {
#       "iterations": 65,
#       "avg": -0.00022700074288290213,
#       "min": -0.1343254178573423,
#       "max": 0.16469949806151662
#     },
#     {
#       "iterations": 70,
#       "avg": 0.00033817979197557846,
#       "min": -0.1577973923323794,
#       "max": 0.11634859766835487
#     },
#     {
#       "iterations": 75,
#       "avg": 0.0008254130613554887,
#       "min": -0.17157510565710335,
#       "max": 0.13555468324855166
#     },
#     {
#       "iterations": 80,
#       "avg": 0.001573171272789103,
#       "min": -0.15188965747246258,
#       "max": 0.12947409058010345
#     },
#     {
#       "iterations": 85,
#       "avg": 0.00307081759150252,
#       "min": -0.12402939294070171,
#       "max": 0.1318802156593215
#     },
#     {
#       "iterations": 90,
#       "avg": -0.0006632219139713548,
#       "min": -0.11431962024130835,
#       "max": 0.1291584904880679
#     },
#     {
#       "iterations": 95,
#       "avg": 0.0006370816794771794,
#       "min": -0.08924062446097562,
#       "max": 0.11288162299998372
#     },
#     {
#       "iterations": 100,
#       "avg": -0.0014187004330760366,
#       "min": -0.10552284373023667,
#       "max": 0.11199464748190073
#     },
#     {
#       "iterations": 105,
#       "avg": -0.00029871268476216073,
#       "min": -0.10721711710139055,
#       "max": 0.12042919365355709
#     },
#     {
#       "iterations": 110,
#       "avg": 0.0023876854878279656,
#       "min": -0.10275006437678763,
#       "max": 0.09388337189637767
#     },
#     {
#       "iterations": 115,
#       "avg": 0.0017459545475512876,
#       "min": -0.09296815963807165,
#       "max": 0.1201435888210413
#     },
#     {
#       "iterations": 120,
#       "avg": -0.000698309285977377,
#       "min": -0.10569675556538544,
#       "max": 0.10360102004369291
#     },
#     {
#       "iterations": 125,
#       "avg": -0.0032566697410882674,
#       "min": -0.09272741502142968,
#       "max": 0.10361881246652666
#     },
#     {
#       "iterations": 130,
#       "avg": -0.0008363525915722821,
#       "min": -0.12306987987437816,
#       "max": 0.11113270516777597
#     },
#     {
#       "iterations": 135,
#       "avg": 0.0025156559781039003,
#       "min": -0.08874040439045623,
#       "max": 0.09910184553515836
#     },
#     {
#       "iterations": 140,
#       "avg": -0.0011467003310708568,
#       "min": -0.08601000586108509,
#       "max": 0.10492443846620111
#     },
#     {
#       "iterations": 145,
#       "avg": -0.004599806570591245,
#       "min": -0.09135756055656885,
#       "max": 0.0751994670353791
#     },
#     {
#       "iterations": 150,
#       "avg": -0.002329087857284313,
#       "min": -0.09628616220517412,
#       "max": 0.09762100726959005
#     },
#     {
#       "iterations": 155,
#       "avg": 0.000660066530688001,
#       "min": -0.11758395979643738,
#       "max": 0.08931031346953584
#     },
#     {
#       "iterations": 160,
#       "avg": 0.00037401225140373367,
#       "min": -0.08197128151586289,
#       "max": 0.09593023332727882
#     },
#     {
#       "iterations": 165,
#       "avg": -0.003023369391477471,
#       "min": -0.09006512191939804,
#       "max": 0.09359092986659423
#     },
#     {
#       "iterations": 170,
#       "avg": -0.000248193337925223,
#       "min": -0.08771266999906545,
#       "max": 0.09972050891421645
#     },
#     {
#       "iterations": 175,
#       "avg": 1.9303197123781956E-05,
#       "min": -0.08168775750924696,
#       "max": 0.0821494810840512
#     },
#     {
#       "iterations": 180,
#       "avg": -0.0012626197360547076,
#       "min": -0.08038323975760761,
#       "max": 0.07556552790551921
#     },
#     {
#       "iterations": 185,
#       "avg": -0.0008036851745125739,
#       "min": -0.09794359465123836,
#       "max": 0.09594835655350664
#     },
#     {
#       "iterations": 190,
#       "avg": 0.0023058726093460455,
#       "min": -0.08369104876058868,
#       "max": 0.07585320193179487
#     },
#     {
#       "iterations": 195,
#       "avg": 0.0020948553924606114,
#       "min": -0.09864002093467301,
#       "max": 0.0795762085290395
#     },
#     {
#       "iterations": 200,
#       "avg": -0.0011792184782968974,
#       "min": -0.09109581115147762,
#       "max": 0.08170647577158607
#     },
#     {
#       "iterations": 205,
#       "avg": -0.003063380981527348,
#       "min": -0.0819568454504406,
#       "max": 0.07224459435080069
#     },
#     {
#       "iterations": 210,
#       "avg": -0.001337284514059567,
#       "min": -0.08074637859842912,
#       "max": 0.07616934984730687
#     },
#     {
#       "iterations": 215,
#       "avg": 0.0017166237752046913,
#       "min": -0.08160409747979264,
#       "max": 0.0685162394132798
#     },
#     {
#       "iterations": 220,
#       "avg": -0.0019988571373786355,
#       "min": -0.08080549942008639,
#       "max": 0.10565513683946373
#     },
#     {
#       "iterations": 225,
#       "avg": -8.075594586579628E-06,
#       "min": -0.0817192160465811,
#       "max": 0.07536957531952312
#     },
#     {
#       "iterations": 230,
#       "avg": 0.00023184118813551855,
#       "min": -0.07835413359890749,
#       "max": 0.07521119915618246
#     },
#     {
#       "iterations": 235,
#       "avg": 0.0021163341367259223,
#       "min": -0.06358955232899077,
#       "max": 0.07044662809457367
#     },
#     {
#       "iterations": 240,
#       "avg": 0.002243350220658934,
#       "min": -0.07285865910487328,
#       "max": 0.08028363452137012
#     },
#     {
#       "iterations": 245,
#       "avg": 0.0012501666278931778,
#       "min": -0.07113661085636556,
#       "max": 0.08307838196864147
#     },
#     {
#       "iterations": 250,
#       "avg": -0.0006236952863188968,
#       "min": -0.08876835992982877,
#       "max": 0.07240633587288195
#     },
#     {
#       "iterations": 255,
#       "avg": -0.001201993637294117,
#       "min": -0.06767358444163872,
#       "max": 0.06955940006936812
#     },
#     {
#       "iterations": 260,

# %%
#r "nuget:XPlot.Plotly.Interactive"
using XPlot.Plotly;
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>XPlot.Plotly.Interactive, 4.0.7</span></li></ul></div></div>
# Loading extensions from `C:\Users\Admin\.nuget\packages\xplot.plotly.interactive\4.0.7\lib\net7.0\XPlot.Plotly.Interactive.dll`
# Configuring PowerShell Kernel for XPlot.Plotly integration.
# Installed support for XPlot.Plotly.

# %%
Chart.Plot(
    new Histogram
    {
        x = data.SelectMany(y => y.values),
        nbinsx = 1000,
    }
)
# Out:
# <!DOCTYPE html>
# <div style="width: 900px; height: 500px;" id="48ec3ece-dcb4-47b7-9f37-27ba9ac4ce4a"></div><script type="text/javascript">
#
# var renderPlotly = function() {
#     var xplotRequire = require.config({context:'xplot-3.0.1',paths:{plotly:'https://cdn.plot.ly/plotly-1.49.2.min'}}) || require;
416233990278E-05,0.0009359437694908342,0.002716487961063808,0.0016158381483917339,-0.0006186122471471639,0.0008378513626958244,-0.0017650595756756363,0.0026051292864209693,0.002011694827109363,0.001837757354298314,9.886475483926985E-05,-0.0005432847197302863,-0.000363118411712098,-0.0005274164330035606,0.0005469384508266333,-0.00043321714002610894,0.0012417972380569895,0.00035617942615492605,-0.0006346243915505145,-0.0009075130755330233,-0.002898641372849697,0.0015966334736710213,-0.002794773958037205,0.0002617218948122681,0.0024336567425187906,-0.002659588906944416,-0.002068189037172906,9.101224585914353E-05,0.002654206755838214,-0.0026018255144175874,0.001274631966439564,-0.0009586695906875476,0.0006732962319948516,-0.0003152169282944659,0.0010694339376622402,-0.0010051087262780505,0.00016430071699185034,0.0024353756688873344,0.0017171926333522753,-0.0003588776844586927,-0.0009204679463185259,-0.00017794187053961295,0.00016126394714971237,0.000175657850422554,1.7881485002752593E-05,0.001008555828054178,0.001374562818636318,-0.0014953011438155453,0.0011653850376785993,0.0003813494970044167,-0.0013574582671374627,-0.0007963632340218718,0.0009212646825613093,-0.00037318644610525936,-0.001292925155787404,-0.00021606862283819782,-0.002526767951396829,0.00039833506441557437,0.0019464634649109158,-0.0004009558430114857,0.0014153503232449012,-0.0004802570591157257,0.0010282670418247598,0.0005764026001503086,-0.0010028401102972295,-0.0007427864404639456,0.0011073661759763121,1.339233449269707E-05,-0.0004467066502116664,0.0012710228142216243,-0.0006156216156381082,-0.001014371716150083,0.0016281813669486124,-0.0008938520739887159,0.0007296436444313384,0.001838363171074389,-0.0014130402519281463,-0.0004363090552265947,-0.00019077311362541456,-0.00048164855774396814,0.001135893354975885,-0.0006151826692495375,-0.0013851844383678243,0.000445409823641887,- ...

# %%
//#i "nuget:https://pkgs.dev.azure.com/dnceng/public/_packaging/dotnet5/nuget/v3/index.json"
//#i "nuget:https://pkgs.dev.azure.com/dnceng/public/_packaging/dotnet-tools/nuget/v3/index.json"

#r "nuget:Microsoft.DotNet.Interactive.ExtensionLab, *-*"
#r "nuget:SandDance.InteractiveExtension"
# Out:
# <div><div></div><div></div><div><strong>Installed Packages</strong><ul><li><span>Microsoft.DotNet.Interactive.ExtensionLab, 1.0.0-beta.23611.1</span></li><li><span>SandDance.InteractiveExtension, 1.0.129</span></li></ul></div></div>
# Loading extension script from `C:\Users\Admin\.nuget\packages\sanddance.interactiveextension\1.0.129\interactive-extensions\dotnet\extension.dib`
# <details><summary>Explore data visually using the <a href="https://github.com/microsoft/SandDance">SandDance Explorer</a>.</summary>
#     <p>This extension adds the ability to sort, filter, and visualize data using the <a href="https://github.com/microsoft/SandDance">SandDance Explorer</a>. Use the <code>ExploreWithSandDance()</code> extension method with variables of type <code>JsonElement</code>, <code>IEnumerable<T></code> or <code>IDataView</code> to render the data explorer.</p>
# <pre>
#     <code>
#     using Microsoft.Data.Analysis;
#     using System.Collections.Generic;
#     using Microsoft.ML;
#
#     var dataFrame = DataFrame.LoadCsv("./Data.csv");
#
#     dataFrame.ExploreWithSandDance().Display();
#     </code>
# </pre>
# <p>To set the SandDance Explorer use the following code</p>
# <pre>
#     <code>
#     DataExplorer.SetDefault<TabularDataResource, SandDanceDataExplorer>();
#     </code>
# </pre>
#     <img src="https://user-images.githubusercontent.com/11507384/54236654-52d42800-44d1-11e9-859e-6c5d297a46d2.gif" width="30%">
#     </details>
# Loading extension script from `C:\Users\Admin\.nuget\packages\microsoft.dotnet.interactive.extensionlab\1.0.0-beta.23611.1\interactive-extensions\dotnet\extension.dib`
# <details><summary>Create strongly-typed dataframes using<code>#!linqify</code>.</summary>
#     <p>The <code>#!linqify</code> magic command replaces a <a href="https://www.nuget.org/packages/Microsoft.Data.Analysis/"><code>Microsoft.Data.Analysis.DataFrame</code></a> variable with a generated, strongly-typed data frame, allowing the use of LINQ operations over the contained data.</p>
#     </details>
# <details><summary>ExplainCode</summary>
#     <p>This extension generates Sequence diagrams from csharp code using Mermaid kernel.</p>
#     </details>
# <details><summary>Inspect code compilation details using the <code>#!inspect</code> magic command.</summary>
#     <p>The <code>#!inspect</code> magic command allows you to see the C# decompilation, IL, and JIT Asm for the code in a C# cell.</p>
#     <img src="https://user-images.githubusercontent.com/547415/109560515-d5749a00-7a90-11eb-9fa3-51b737345bb4.png" width="75%" />
#     </details>
# <details><summary>Use the <code>#!record</code> magic command to keep a transcript of the code you run.</summary>
#     <p>Once you enable transcripts using <code>#!record</code>, each code submission (including re-running cells) is recorded in the specified file. The JSON format used is the same format recognized by the .NET Interactive <code>stdio</code> and <code>http</code> APIs and can be used to replay an interactive session via automation.</p>
#     <img src="https://user-images.githubusercontent.com/547415/109562409-343b1300-7a93-11eb-8ebf-79bb6af028cf.png" width="75%" />
#     </details>
# Loading extensions from `C:\Users\Admin\.nuget\packages\microsoft.data.analysis\0.21.0\interactive-extensions\dotnet\Microsoft.Data.Analysis.Interactive.dll`

# %%
matrix.ExploreWithSandDance()
# Out:
# <div style="background-color:white;">
# <div id="77bef0a2954744bb90f502a1753331a2" style="height: 100ch ;margin: 2px;">
# </div>
# <script type="text/javascript">
#
# renderSandDanceExplorer_77bef0a2954744bb90f502a1753331a2 = () => {
#
#     (require.config({ 'paths': { 'context': '1.0.100', 'sandDanceUri' : 'https://colombod.github.io/dotnet-interactive-cdn/extensionlab/1.0.100/SandDance/sanddanceapi', 'urlArgs': 'cacheBuster=9f64860fba25403680172d98022d8fda' }}) || require)(['sandDanceUri'], (sandDance) => {
#
#         sandDance.createSandDanceExplorer({
#             data: {
#   "profile": "tabular-data-resource",
#   "schema": {
#     "primaryKey": [],
#     "fields": [
#       {
#         "type": "integer",
#         "name": "iterations"
#       },
#       {
#         "type": "number",
#         "name": "avg"
#       },
#       {
#         "type": "number",
#         "name": "min"
#       },
#       {
#         "type": "number",
#         "name": "max"
#       }
#     ]
#   },
#   "data": [
#     {
#       "iterations": 5,
#       "avg": -0.003457220237605317,
#       "min": -0.4406839013454061,
#       "max": 0.4901650628420658
#     },
#     {
#       "iterations": 10,
#       "avg": 0.015036257162826689,
#       "min": -0.3217961935581301,
#       "max": 0.4040635852614901
#     },
#     {
#       "iterations": 15,
#       "avg": 0.0013355054960569883,
#       "min": -0.28862192259228453,
#       "max": 0.22321726119875487
#     },
#     {
#       "iterations": 20,
#       "avg": -0.011061899122384186,
#       "min": -0.25807857115645244,
#       "max": 0.261122361730794
#     },
#     {
#       "iterations": 25,
#       "avg": -0.001143456132281971,
#       "min": -0.255719364946782,
#       "max": 0.2505482407796583
#     },
#     {
#       "iterations": 30,
#       "avg": -0.004854947252508474,
#       "min": -0.18629347691632114,
#       "max": 0.1890976891580129
#     },
#     {
#       "iterations": 35,
#       "avg": 0.00016880122627247358,
#       "min": -0.2186415689694388,
#       "max": 0.22227199575700368
#     },
#     {
#       "iterations": 40,
#       "avg": 0.0006687601723356142,
#       "min": -0.16639494696334228,
#       "max": 0.21714547815899712
#     },
#     {
#       "iterations": 45,
#       "avg": 0.002098795156089168,
#       "min": -0.20392907088564544,
#       "max": 0.15480899409937396
#     },
#     {
#       "iterations": 50,
#       "avg": -0.002168611428435929,
#       "min": -0.15627959941818156,
#       "max": 0.2031872597100364
#     },
#     {
#       "iterations": 55,
#       "avg": 0.001521426783796889,
#       "min": -0.18496059427004907,
#       "max": 0.17970005420493598
#     },
#     {
#       "iterations": 60,
#       "avg": -0.0002063301386527128,
#       "min": -0.14721825226756233,
#       "max": 0.13994112614152157
#     },
#     {
#       "iterations": 65,
#       "avg": -0.002147865433427945,
#       "min": -0.15784148268420106,
#       "max": 0.1763788847896091
#     },
#     {
#       "iterations": 70,
#       "avg": 0.0070502360117037245,
#       "min": -0.18338255329713402,
#       "max": 0.1618195295265973
#     },
#     {
#       "iterations": 75,
#       "avg": 0.00010565522363354342,
#       "min": -0.1167006164106891,
#       "max": 0.16563462405284737
#     },
#     {
#       "iterations": 80,
#       "avg": 0.004246806364837187,
#       "min": -0.14366994157202279,
#       "max": 0.13016639346922404
#     },
#     {
#       "iterations": 85,
#       "avg": -0.0047117499599294045,
#       "min": -0.11769561421089939,
#       "max": 0.11843801883645899
#     },
#     {
#       "iterations": 90,
#       "avg": 0.0016848223510402783,
#       "min": -0.13295555629229364,
#       "max": 0.12872202800033417
#     },
#     {
#       "iterations": 95,
#       "avg": 0.0019203436058096905,
#       "min": -0.1115427545647528,
#       "max": 0.16559963061579472
#     },
#     {
#       "iterations": 100,
#       "avg": -0.0021535536399505217,
#       "min": -0.13955030042906502,
#       "max": 0.09710900729014424
#     },
#     {
#       "iterations": 105,
#       "avg": 0.0008002125064774231,
#       "min": -0.11881914794368657,
#       "max": 0.1135119726134068
#     },
#     {
#       "iterations": 110,
#       "avg": -0.002514036851032509,
#       "min": -0.10224614849418656,
#       "max": 0.09748890314993383
#     },
#     {
#       "iterations": 115,
#       "avg": -0.0026560325475754355,
#       "min": -0.10551738239699829,
#       "max": 0.10480543590861781
#     },
#     {
#       "iterations": 120,
#       "avg": -0.0014555872626638528,
#       "min": -0.0953550717469545,
#       "max": 0.11526605932277591
#     },
#     {
#       "iterations": 125,
#       "avg": -0.002528836697923787,
#       "min": -0.10475140466775057,
#       "max": 0.10336928444974797
#     },
#     {
#       "iterations": 130,
#       "avg": -0.005037100364901112,
#       "min": -0.1180477586709926,
#       "max": 0.0846230946275829
#     },
#     {
#       "iterations": 135,
#       "avg": -0.0003884922849868518,
#       "min": -0.12047424989239575,
#       "max": 0.10120058695255736
#     },
#     {
#       "iterations": 140,
#       "avg": -0.0014830902375113383,
#       "min": -0.09752900565839595,
#       "max": 0.09980760855776995
#     },
#     {
#       "iterations": 145,
#       "avg": -7.771819648735214E-05,
#       "min": -0.10362899317045063,
#       "max": 0.07604420356100734
#     },
#     {
#       "iterations": 150,
#       "avg": -4.9574481454536154E-05,
#       "min": -0.10767346366993562,
#       "max": 0.09335677119485732
#     },
#     {
#       "iterations": 155,
#       "avg": -0.00015283678018608614,
#       "min": -0.07358114692751777,
#       "max": 0.1164026233393391
#     },
#     {
#       "iterations": 160,
#       "avg": 0.0008119955971746714,
#       "min": -0.0965103809336614,
#       "max": 0.09676318290132552
#     },
#     {
#       "iterations": 165,
#       "avg": 0.00029328899003528954,
#       "min": -0.07745812495687983,
#       "max": 0.092887219949222
#     },
#     {
#       "iterations": 170,
#       "avg": -0.0019554710977874247,
#       "min": -0.06942253380969354,
#       "max": 0.0882755103324816
#     },
#     {
#       "iterations": 175,
#       "avg": 0.0012496516806444124,
#       "min": -0.08837273611717184,
#       "max": 0.10469298439497951
#     },
#     {
#       "iterations": 180,
#       "avg": -5.290416233990278E-05,
#       "min": -0.07317473214232015,
#       "max": 0.088673245463315
#     },
#     {
#       "iterations": 185,
#       "avg": 0.0009359437694908342,
#       "min": -0.08157775837876606,
#       "max": 0.07486234644872025
#     },
#     {
#       "iterations": 190,
#       "avg": 0.002716487961063808,
#       "min": -0.08362297325810335,
#       "max": 0.07550396892954485
#     },
#     {
#       "iterations": 195,
#       "avg": 0.0016158381483917339,
#       "min": -0.11477685251363741,
#       "max": 0.068506898736655
#     },
#     {
#       "iterations": 200,
#       "avg": -0.0006186122471471639,
#       "min": -0.11458510561876041,
#       "max": 0.08893406214573563
#     },
#     {
#       "iterations": 205,
#       "avg": 0.0008378513626958244,
#       "min": -0.07556257021958593,
#       "max": 0.06988464869839077
#     },
#     {
#       "iterations": 210,
#       "avg": -0.0017650595756756363,
#       "min": -0.08282152370489972,
#       "max": 0.06851850935293978
#     },
#     {
#       "iterations": 215,
#       "avg": 0.0026051292864209693,
#       "min": -0.07269484426152582,
#       "max": 0.0890745440605962
#     },
#     {
#       "iterations": 220,
#       "avg": 0.002011694827109363,
#       "min": -0.06232710639828688,
#       "max": 0.08289876148629143
#     },
#     {
#       "iterations": 225,
#       "avg": 0.001837757354298314,
#       "min": -0.08478815484073235,
#       "max": 0.08138815708578426
#     },
#     {
#       "iterations": 230,
#       "avg": 9.886475483926985E-05,
#       "min": -0.08682461424933667,
#       "max": 0.09383447935262501
#     },
#     {
#       "iterations": 235,
#       "avg": -0.0005432847197302863,
#       "min": -0.0679158422145871,
#       "max": 0.08389894975693873
#     },
#     {
#       "iterations": 240,
#       "avg": -0.000363118411712098,
#       "min": -0.08889486142409801,
#       "max": 0.07698553867820458
#     },
#     {
#       "iterations": 245,
#       "avg": -0.0005274164330035606,
#       "min": -0.07601798967741856,
#       "max": 0.06954824303497349
#     },
#     {
#       "iterations": 250,
#       "avg": 0.0005469384508266333,
#       "min": -0.0793625975093204,
#       "max": 0.07065814419227
