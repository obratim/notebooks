// %%
class Wrapper<T>
{
    public T Value { get; set; }
}

// %%
static class EnumParseHelper
{
    public static bool TryParse<T>(string raw, Wrapper<T> result)
        where T : struct
    {
        T tmp;
        if (Enum.TryParse(raw, true, out tmp))
        {
            result.Value = tmp;
            return true;
        }
        return false;
    }
}

// %%
using System.ComponentModel;

static class SetterFromConfigHelper<T>
{
    private static readonly Action<T, Func<string, string>>[] Fillers;
    static SetterFromConfigHelper()
    {
        var properties = TypeDescriptor.GetProperties(typeof(T));
        var fillers = new List<Action<T, Func<string, string>>>(properties.Count);

        AddFillers(fillers, properties, "", x => x);

        Fillers = fillers.ToArray();
    }

    private static void AddFillers (List<Action<T, Func<string, string>>> fillers, PropertyDescriptorCollection properties, string prefix, Func<T, object?> valueGetter)
    {
        var methodInfo = typeof(EnumParseHelper).GetMethod("TryParse");
        var wrapperType = typeof(Wrapper<>);

        static void SetValue<TValue>(T self, Func<T, object?> valueGetter, PropertyDescriptor propertyDescriptor, TValue value)
        {
            var subSelf = valueGetter(self);
            if (subSelf != null)
                propertyDescriptor.SetValue(subSelf, value);
        }

        foreach (PropertyDescriptor pd in properties)
        {
            if (!(pd?.IsReadOnly == false || !pd.PropertyType.FullName.StartsWith("System.")))
                continue;
            
            if (pd.PropertyType == typeof(string))
            {
                fillers.Add(
                    (self, getter) =>
                    {
                        var raw = getter(prefix + pd.Name);
                        if (raw == null)
                            return;
                        SetValue(self, valueGetter, pd, raw);
                    });
            }
            else if (pd.PropertyType == typeof(bool))
            {
                fillers.Add(
                    (self, getter) =>
                    {
                        var raw = getter(prefix + pd.Name);
                        if (raw == null)
                            return;
                        bool result;
                        if (bool.TryParse(raw, out result))
                            SetValue(self, valueGetter, pd, result);
                    });
            }
            else if (pd.PropertyType == typeof(byte))
            {
                fillers.Add(
                    (self, getter) =>
                    {
                        var raw = getter(prefix + pd.Name);
                        if (raw == null)
                            return;
                        byte result;
                        if (byte.TryParse(raw, out result))
                            SetValue(self, valueGetter, pd, result);
                    });
            }
            else if (pd.PropertyType == typeof(short))
            {
                fillers.Add(
                    (self, getter) =>
                    {
                        var raw = getter(prefix + pd.Name);
                        if (raw == null)
                            return;
                        short result;
                        if (short.TryParse(raw, out result))
                            SetValue(self, valueGetter, pd, result);
                    });
            }
            else if (pd.PropertyType == typeof(int))
            {
                fillers.Add(
                    (self, getter) =>
                    {
                        var raw = getter(prefix + pd.Name);
                        if (raw == null)
                            return;
                        int result;
                        if (int.TryParse(raw, out result))
                            SetValue(self, valueGetter, pd, result);
                    });
            }
            else if (pd.PropertyType == typeof(long))
            {
                fillers.Add(
                    (self, getter) =>
                    {
                        var raw = getter(prefix + pd.Name);
                        if (raw == null)
                            return;
                        long result;
                        if (long.TryParse(raw, out result))
                            SetValue(self, valueGetter, pd, result);
                    });
            }
            else if (pd.PropertyType == typeof(float))
            {
                fillers.Add(
                    (self, getter) =>
                    {
                        var raw = getter(prefix + pd.Name);
                        if (raw == null)
                            return;
                        float result;
                        if (float.TryParse(raw, System.Globalization.NumberStyles.Any, System.Globalization.CultureInfo.InvariantCulture, out result))
                            SetValue(self, valueGetter, pd, result);
                    });
            }
            else if (pd.PropertyType == typeof(double))
            {
                fillers.Add(
                    (self, getter) =>
                    {
                        var raw = getter(prefix + pd.Name);
                        if (raw == null)
                            return;
                        double result;
                        if (double.TryParse(raw, System.Globalization.NumberStyles.Any, System.Globalization.CultureInfo.InvariantCulture, out result))
                            SetValue(self, valueGetter, pd, result);
                    });
            }
            else if (pd.PropertyType == typeof(decimal))
            {
                fillers.Add(
                    (self, getter) =>
                    {
                        var raw = getter(prefix + pd.Name);
                        if (raw == null)
                            return;
                        decimal result;
                        if (decimal.TryParse(raw, System.Globalization.NumberStyles.Any, System.Globalization.CultureInfo.InvariantCulture, out result))
                            SetValue(self, valueGetter, pd, result);
                    });
            }
            else if (pd.PropertyType == typeof(DateTime))
            {
                fillers.Add(
                    (self, getter) =>
                    {
                        var raw = getter(prefix + pd.Name);
                        if (raw == null)
                            return;
                        DateTime result;
                        if (DateTime.TryParse(raw, System.Globalization.CultureInfo.InvariantCulture, System.Globalization.DateTimeStyles.AllowWhiteSpaces, out result))
                            SetValue(self, valueGetter, pd, result);
                    });
            }
            else if (pd.PropertyType == typeof(TimeSpan))
            {
                fillers.Add(
                    (self, getter) =>
                    {
                        var raw = getter(prefix + pd.Name);
                        if (raw == null)
                            return;
                        TimeSpan result;
                        if (TimeSpan.TryParse(raw, out result))
                            SetValue(self, valueGetter, pd, result);
                    });
            }
            else if (pd.PropertyType == typeof(Encoding))
            {
                fillers.Add(
                    (self, getter) =>
                    {
                        var raw = getter(prefix + pd.Name);
                        if (raw == null)
                            return;
                        try
                        {
                            pd.SetValue(self, Encoding.GetEncoding(raw));
                        }
                        catch { }
                    });
            }
            else if (pd.PropertyType == typeof(sbyte))
            {
                fillers.Add(
                    (self, getter) =>
                    {
                        var raw = getter(prefix + pd.Name);
                        if (raw == null)
                            return;
                        sbyte result;
                        if (sbyte.TryParse(raw, out result))
                            SetValue(self, valueGetter, pd, result);
                    });
            }
            else if (pd.PropertyType == typeof(ushort))
            {
                fillers.Add(
                    (self, getter) =>
                    {
                        var raw = getter(prefix + pd.Name);
                        if (raw == null)
                            return;
                        ushort result;
                        if (ushort.TryParse(raw, out result))
                            SetValue(self, valueGetter, pd, result);
                    });
            }
            else if (pd.PropertyType == typeof(uint))
            {
                fillers.Add(
                    (self, getter) =>
                    {
                        var raw = getter(prefix + pd.Name);
                        if (raw == null)
                            return;
                        uint result;
                        if (uint.TryParse(raw, out result))
                            SetValue(self, valueGetter, pd, result);
                    });
            }
            else if (pd.PropertyType == typeof(ulong))
            {
                fillers.Add(
                    (self, getter) =>
                    {
                        var raw = getter(prefix + pd.Name);
                        if (raw == null)
                            return;
                        ulong result;
                        if (ulong.TryParse(raw, out result))
                            SetValue(self, valueGetter, pd, result);
                    });
            }
            else if (pd.PropertyType.IsEnum)
            {
                if (methodInfo == null)
                    throw new Exception("Type not found");
                var genericMethodInfo = methodInfo.MakeGenericMethod(pd.PropertyType);
                var resultType = wrapperType.MakeGenericType(pd.PropertyType);
                fillers.Add(
                    (self, getter) =>
                    {
                        var raw = getter(prefix + pd.Name);
                        if (raw == null)
                            return;
                        var result = Activator.CreateInstance(resultType);
                        var success = genericMethodInfo.Invoke(null, new object[] { raw, result });
                        if ((bool)success)
                            pd.SetValue(self, resultType.GetProperty(nameof(Wrapper<int>.Value)).GetValue(result));
                    });
            }
            else // if (!pd.PropertyType.FullName.StartsWith("System."))
            {
                AddFillers(fillers, TypeDescriptor.GetProperties(pd.PropertyType), pd.Name + '.', self => 
                {
                    var subself = pd.GetValue(self);
                    if (subself != null)
                        return subself;
                    if (pd.IsReadOnly)
                        return null;
                    var constructor = pd.PropertyType.GetConstructor(Type.EmptyTypes);
                    if (constructor == null)
                        return null;
                    subself = constructor.Invoke(Array.Empty<object>());
                    pd.SetValue(self, subself);
                    return subself;
                });
            }
        }
    }

    public static T FillFromConfig(T self, Func<string, string> valueFromConfig)
    {
        foreach (var filler in Fillers)
        {
            filler.Invoke(self, valueFromConfig);
        }

        return self;
    }
}

static class SetterFromConfigHelper
{
    public static T FillFromConfig<T>(/*this*/ T self, Func<string, string> valueFromConfigGetter)
        =>
            SetterFromConfigHelper<T>.FillFromConfig(self, valueFromConfigGetter);
}

// %%
var settings = new Dictionary<string, string>
{
    ["x"] = "1",
    ["y"] = "2",
    ["z"] = "3",
    ["kind"] = "utc",
    ["flag"] = "true",
    ["time"] = "   2023.01.01  16:55:17 Z ",
    ["a.b"] = "=============",
};

class Foo
{
    public int x { get; set; }
    public double y { get; set; }
    public decimal z { get; set; }
    public bool flag { get; set; }
    public DateTime time { get; set; }
    public DateTimeKind kind { get; set; }
    public Bar a { get; set; }
}

class Bar
{
    public string b { get; set; }
}

string SettingGetter(string key) => settings.TryGetValue(key, out var result) ? result : null;

SetterFromConfigHelper.FillFromConfig(new Foo(), SettingGetter)
// Out:
// <details open="open" class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#7+Foo</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>x</td><td><div class="dni-plaintext"><pre>1</pre></div></td></tr><tr><td>y</td><td><div class="dni-plaintext"><pre>2</pre></div></td></tr><tr><td>z</td><td><div class="dni-plaintext"><pre>3</pre></div></td></tr><tr><td>flag</td><td><div class="dni-plaintext"><pre>True</pre></div></td></tr><tr><td>time</td><td><span>2023-01-01 19:55:17Z</span></td></tr><tr><td>kind</td><td><span>Utc</span></td></tr><tr><td>a</td><td><details class="dni-treeview"><summary><span class="dni-code-hint"><code>Submission#7+Bar</code></span></summary><div><table><thead><tr></tr></thead><tbody><tr><td>b</td><td><div class="dni-plaintext"><pre>=============</pre></div></td></tr></tbody></table></div></details></td></tr></tbody></table></div></details><style>
// .dni-code-hint {
//     font-style: italic;
//     overflow: hidden;
//     white-space: nowrap;
// }
// .dni-treeview {
//     white-space: nowrap;
// }
// .dni-treeview td {
//     vertical-align: top;
//     text-align: start;
// }
// details.dni-treeview {
//     padding-left: 1em;
// }
// table td {
//     text-align: start;
// }
// table tr {
//     vertical-align: top;
//     margin: 0em 0px;
// }
// table tr td pre
// {
//     vertical-align: top !important;
//     margin: 0em 0px !important;
// }
// table th {
//     text-align: start;
// }
// </style>
